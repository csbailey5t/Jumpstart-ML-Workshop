# %%
import gensim
from gensim.parsing.preprocessing import STOPWORDS
import glob
import itertools
import nltk
from nltk.tokenize import word_tokenize
import os
from tqdm import tqdm

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
def head(stream, n=10):
    return list(itertools.islice(stream, n))

# %%
# Given a filename, return just the unique id
def get_item_id(fn):
    return os.path.split(fn)[1].split(".")[0]

# %%
def tokenize(text):
    tokens = [token for token in word_tokenize(text) if token.lower() not in STOPWORDS]
    cleaned = [token for token in tokens if token.isalpha()]
    cleaned_greater_1 = [token for token in cleaned if len(token) > 1]
    return cleaned_greater_1

# %%
def text_stream(text_dir):
    # yield each item ocr as (id, tokens) tuple
    for fn in glob.glob(f"{text_dir}/*.txt"):
        item_id = get_item_id(fn)
        with open(fn, 'r') as f:
            document = f.read()
            yield(item_id, tokenize(document))

# %%
# text_dir = "texts"
text_dir = "/gdrive/Shared drives/Data & Visualization Services/Workshops/Jumpstart/texts"

# %%
head(text_stream(text_dir), n=2)
# Out:
# [('mc00344_118824_20200131_1256',
#   ['Stereotaxic',
#    'instruments',
#    'cat',
#    'dog',
#    'rabbit',
#    'Stereotaxic',
#    'instruments',
#    'hold',
#    'animals',
#    'paralyzed',
#    'curariform',
#    'drugs',
#    'general',
#    'anesthesia',
#    'cases',
#    'general',
#    'anesthesia',
#    'allowed',
#    'wear',
#    'conscious',
#    'animal',
#    'kept',
#    'instrument',
#    'brain',
#    'research',
#    'storage',
#    'refrigerator',
#    'expired',
#    'medications',
#    'bag',
#    'black',
#    'rotted',
#    'apples',
#    'fed',
#    'monkeys',
#    'rewards',
#    'experiments',
#    'um',
#    'um',
#    'mu',
#    'guns',
#    'mom',
#    'uuwmt',
#    'unrﬂ',
#    'ﬂwv',
#    'NW',
#    'rel',
#    'lh',
#    'UIt',
#    'rqul',
#    'whim',
#    'new',
#    'Int',
#    'ot',
#    'Ioluuon',
#    'shou',
#    'Lot',
#    'Manon',
#    'Duo',
#    'medications',
#    'expiration',
#    'date',
#    'September',
#    'refrigerator',
#    'Photographs',
#    'Institute',
#    'Behavioral',
#    'Research',
#    'Monkey',
#    'deteriorating',
#    'bandage',
#    'stayed',
#    'weeks',
#    'Note',
#    'upper',
#    'arm',
#    'bandage',
#    'Monkey',
#    'awaiting',
#    'acute',
#    'noxious',
#    'stimuli',
#    'test',
#    'confined',
#    'monkey',
#    'chair',
#    'Photographs',
#    'Institute',
#    'Behavioral',
#    'Research',
#    'Jﬁ',
#    'xt',
#    'Monkey',
#    'chairs',
#    'cause',
#    'great',
#    'stress',
#    'occupants',
#    'maintaining',
#    'indwelling',
#    'catheters',
#    'long',
#    'periods',
#    'time',
#    'substitute',
#    'laboratories',
#    'including',
#    'Fort',
#    'Detrick',
#    'laboratories',
#    'continue',
#    'force',
#    'monkeys',
#    'chairs',
#    'MM',
#    'Monkey',
#    'deteriorating',
#    'bandage',
#    'stayed',
#    'weeks',
#    'Note',
#    'upper',
#    'arm',
#    'bandage',
#    'Monkey',
#    'awaiting',
#    'acute',
#    'noxious',
#    'stimuli',
#    'test',
#    'confined',
#    'monkey',
#    'chair',
#    'Photographs',
#    'Institute',
#    'Behavioral',
#    'Research',
#    'Jﬁ',
#    'xt',
#    'Monkey',
#    'chairs',
#    'cause',
#    'great',
#    'stress',
#    'occupants',
#    'maintaining',
#    'indwelling',
#    'catheters',
#    'long',
#    'periods',
#    'time',
#    'substitute',
#    'laboratories',
#    'including',
#    'Fort',
#    'Detrick',
#    'laboratories',
#    'continue',
#    'force',
#    'monkeys',
#    'chairs',
#    'MM']),
#  ('mc00456-001-bx0007-013-001',
#   ['Abolition',
#    'Viviseotion',
#    'ARRANGEMENT',
#    'CLAUSES',
#    'Clause',
#    'Short',
#    'title',
#    'Deﬁnition',
#    'Vivisection',
#    'Prohibition',
#    'Vivisection',
#    'Penalty',
#    'Vivisection',
#    'Entry',
#    'warrant',
#    'justice',
#    'Prosecution',
#    'offences',
#    'recovery',
#    'penalties',
#    'England',
#    'Power',
#    'offender',
#    'England',
#    'elect',
#    'tried',
#    'indictment',
#    'Summary',
#    'jurisdiction',
#    'Form',
#    'appeal',
#    'quarter',
#    'sessions',
#    'Prosecution',
#    'offences',
#    'recovery',
#    'penalties',
#    'Scotland',
#    'Prosecution',
#    'offences',
#    'recovery',
#    'penalties',
#    'Ireland',
#    'Power',
#    'offender',
#    'Ireland',
#    'elect',
#    'tried',
#    'indictment',
#    'summaryjurisdiction',
#    'Repeal',
#    'Cruelty',
#    'Animals',
#    'Act',
#    'Abolition',
#    'Vivisection',
#    'Abolition',
#    'expedient',
#    'amend',
#    'law',
#    'relating',
#    'cruelty',
#    'animals',
#    'cases',
#    'animals',
#    'medical',
#    'physiological',
#    'scientiﬁc',
#    'puiposes',
#    'View',
#    'advanCement',
#    'new',
#    'physiological',
#    'knowledge',
#    'useful',
#    'saving',
#    'life',
#    'alleviating',
#    'suffering',
#    'purpose',
#    'testing',
#    'discovery',
#    'alleged',
#    'advancement',
#    'knowledge',
#    'illustration',
#    'lectures',
#    'medical',
#    'schools',
#    'hospitals',
#    'colleges',
#    'subjected',
#    'alive',
#    'inoculations',
#    'expeliments',
#    'calculated',
#    'cause',
#    'pain',
#    'enacted',
#    'King',
#    'Excellent',
#    'Majesty',
#    'advice',
#    'consent',
#    'Lords',
#    'Spiritual',
#    'Commons',
#    'present',
#    'Parliament',
#    'assembled',
#    'authority',
#    'follows',
#    'Act',
#    'cited',
#    'purposes',
#    'Vivisection',
#    'Short',
#    'Title',
#    'Abolition',
#    'Act',
#    'Term',
#    'Vivisection',
#    'Act',
#    'shall',
#    'mean',
#    'inoculation',
#    'Dsﬁnitiqn',
#    'performed',
#    'use',
#    'anaesthetics',
#    'nature',
#    'produce',
#    'pain',
#    'ate',
#    'animal',
#    'cutting',
#    'wounding',
#    'living',
#    'vertebrate',
#    'animal',
#    'inﬂuence',
#    'anaesthetic',
#    'purpose',
#    'Curing',
#    'ating',
#    'injury',
#    'disease',
#    'animal',
#    'suffering',
#    'self',
#    'protection',
#    'purpose',
#    'gelding',
#    'domestic',
#    'animal',
#    'purpose',
#    'killing',
#    'animal',
#    'shall',
#    'lawful',
#    'subject',
#    'ate',
#    'animal',
#    'section',
#    'Provided',
#    'shall',
#    'cut',
#    'wound',
#    'living',
#    'injured',
#    'diseased',
#    'vertebrate',
#    'animal',
#    'purpose',
#    'alleviating',
#    'injury',
#    'disease',
#    'animal',
#    'suffering',
#    'cut',
#    'oz',
#    'wound',
#    'living',
#    'veitebrate',
#    'animal',
#    'purpose',
#    'self',
#    'protection',
#    'cut',
#    'wound',
#    'domestic',
#    'animal',
#    'purpose',
#    'gelding',
#    'cut',
#    'wound',
#    'animal',
#    'killing',
#    'Penalty',
#    'Vivisection',
#    'Entry',
#    'Warrant',
#    'Justice',
#    'Prosecution',
#    'oi',
#    'offences',
#    'recovery',
#    'penalties',
#    'England',
#    'Court',
#    'Summary',
#    'Abolition',
#    'Vivisection',
#    'person',
#    'subjecting',
#    'vertebrate',
#    'animal',
#    'Vivisection',
#    'save',
#    'Act',
#    'provided',
#    'shall',
#    'guilty',
#    'offence',
#    'shall',
#    'ﬁrst',
#    'offence',
#    'liable',
#    'penalty',
#    'exceeding',
#    'ﬁfty',
#    'pounds',
#    'second',
#    'subsequent',
#    'offence',
#    'liable',
#    'imprisonment',
#    'period',
#    'exceeding',
#    'months',
#    'Legal',
#    'Proceedings',
#    'justice',
#    'peace',
#    'information',
#    'oath',
#    'reasonable',
#    'ground',
#    'believe',
#    'Vivisection',
#    'contraventiOn',
#    'Act',
#    'intended',
#    'performed',
#    'place',
#    'shall',
#    'issue',
#    'warrant',
#    'authorizing',
#    'ofﬁcer',
#    'constable',
#    'police',
#    'accompanied',
#    'person',
#    'persons',
#    'said',
#    'justice',
#    'shall',
#    'direct',
#    'enter',
#    'search',
#    'place',
#    'names',
#    'addresses',
#    'persons',
#    'seize',
#    'away',
#    'living',
#    'vertebrate',
#    'animal',
#    'Vivisection',
#    'performed',
#    'intended',
#    'performed',
#    'materials',
#    'instruments',
#    'intended',
#    'Vivisection',
#    'police',
#    'officer',
#    'constable',
#    'authorized',
#    'ﬁnds',
#    'place',
#    'living',
#    'vertebrate',
#    'animal',
#    'Vivisection',
#    'performed',
#    'kill',
#    'cause',
#    'person',
#    'kill',
#    'painless',
#    'manner',
#    'possible',
#    'person',
#    'refuses',
#    'admission',
#    'demand',
#    'police',
#    'oﬁicer',
#    'constable',
#    'authorized',
#    'person',
#    'directed',
#    'accompany',
#    'obstructs',
#    'ofﬁcer',
#    'constable',
#    'execution',
#    'duty',
#    'section',
#    'refuses',
#    'demand',
#    'disclose',
#    'address',
#    'shall',
#    'liable',
#    'penalty',
#    'exceeding',
#    'ﬁve',
#    'pounds',
#    'England',
#    'offences',
#    'Act',
#    'prosecuted',
#    'penalties',
#    'Act',
#    'recovered',
#    'court',
#    'summary',
#    'jurisdiction',
#    'manner',
#    'directed',
#    'Summary',
#    'Jurisdiction',
#    'Act',
#    'England',
#    'Summary',
#    'Jurisdiction',
#    'Act',
#    'means',
#    'Act',
#    'Session',
#    'eleventh',
#    'twelfth',
#    'years',
#    'reign',
#    'late',
#    'Majesty',
#    'chapter',
#    'intituled',
#    'Act',
#    'facilitate',
#    'performance',
#    'duties',
#    'justices',
#    'peace',
#    'sessions',
#    'England',
#    'Wales',
#    'respect',
#    'summary',
#    'convictions',
#    'orders',
#    'Act',
#    'amending',
#    'theisame',
#    'Court',
#    'summary',
#    'jurisdiction',
#    'means',
#    'includes',
#    'justice',
#    'justices',
#    'peace',
#    'metropolitan',
#    'police',
#    'magistrate',
#    'stipendiary',
#    'magistrate',
#    'ofﬁcer',
#    'called',
#    'exercising',
#    'jurisdiction',
#    'pursuance',
#    'Summary',
#    'Jurisdiction',
#    'Act',
#    'Provided',
#    'court',
#    'hearing',
#    'determining',
#    'information',
#    'Act',
#    'shall',
#    'constituted',
#    'justices',
#    'peace',
#    'petty',
#    'sessions',
#    'sitting',
#    'place',
#    'appointed',
#    'holding',
#    'petty',
#    'sessions',
#    'Abolition',
#    'Vivisection',
#    'magistiate',
#    'ofﬁcer',
#    'sitting',
#    'place',
#    'appointed',
#    'justice',
#    'time',
#    'empowered',
#    'law',
#    'act',
#    'authorized',
#    'justice',
#    'peace',
#    'England',
#    'person',
#    'accused',
#    'fggﬁeffin',
#    'summary',
#    'juiisdiction',
#    'offence',
#    'Act',
#    'England',
#    'penalty',
#    'ﬁve',
#    'pounds',
#    'imposed',
#    'accused',
#    'appeaIing',
#    'dictment',
#    'objects',
#    'tried',
#    'offence',
#    'court',
#    'rtnlr',
#    'ary',
#    'court',
#    'summary',
#    'jurisdiction',
#    'tion',
#    'deal',
#    'case',
#    'accused',
#    'chaiged',
#    'indictable',
#    'offence',
#    'offence',
#    'punishable',
#    'summary',
#    'conviction',
#    'offence',
#    'prosecuted',
#    'indictment',
#    'accordingly',
#    'England',
#    'party',
#    'thinks',
#    'aggrieved',
#    'Egggffo',
#    'conviction',
#    'quarter',
#    'information',
#    'Act',
#    'party',
#    'aggrieved',
#    'appeal',
#    'therefrom',
#    'subject',
#    'conditions',
#    'regulations',
#    'fOllowing',
#    'appeal',
#    'shall',
#    'court',
#    'general',
#    'sessions',
#    'county',
#    'place',
#    'cause',
#    'appeal',
#    'arisen',
#    'bolden',
#    'days',
#    'court',
#    'appeal',
#    'appellant',
#    'shall',
#    'days',
#    'cause',
#    'appeal',
#    'notice',
#    'court',
#    'Jurisdiction',
#    'intention',
#    'appeal',
#    'ground',
#    'thereof',
#    'appellant',
#    'shall',
#    'days',
#    'notice',
#    'enter',
#    'Justice',
#    'peace',
#    'sufﬁcient',
#    'sureties',
#    'conditioned',
#    'personally',
#    'tiy',
#    'appeal',
#    'abide',
#    'judgment',
#    'court',
#    'thereon',
#    'pay',
#    'costs',
#    'court',
#    'security',
#    'deposit',
#    'money',
#    'Justice',
#    'allow',
#    'appellant',
#    'custody',
#    'Justice',
#    'think',
#    'fit',
#    'appellant',
#    'entering',
#    'recognizance',
#    'giving',
#    'security',
#    'aforesaid',
#    'custody',
#    'court',
#    'appeal',
#    'adjourn',
#    'appeal',
#    'hearing',
#    'thereof',
#    'conﬁrm',
#    'reverse',
#    'modify',
#    'decision',
#    'court',
#    'summary',
#    'jurisdiction',
#    'remit',
#    'matter',
#    'court',
#    'summary',
#    'jurisdiction',
#    'opinion',
#    'court',
#    'appeal',
#    'thereon',
#    'order',
#    'matter',
#    'court',
#    'thinks',
#    'matter',
#    'remitted',
#    'court',
#    'summary',
#    'jurisdiction',
#    'said',
#    'court',
#    'shall',
#    'decide',
#    'information',
#    'Prosecution',
#    'offences',
#    'recovery',
#    'penalties',
#    'Scotland',
#    'ProsecutiOn',
#    'offences',
#    'recovery',
#    'penalties',
#    'Ireland',
#    'Power',
#    'offender',
#    'Ireland',
#    'elect',
#    'tried',
#    'dictment',
#    'summary',
#    'jurisdiction',
#    'Repeal',
#    'Cruelty',
#    'Animals',
#    'Act',
#    'Abolition',
#    'Vivisection',
#    'accordance',
#    'order',
#    'said',
#    'court',
#    'appeal',
#    'court',
#    'appeal',
#    'order',
#    'costs',
#    'paid',
#    'party',
#    'court',
#    'thinks',
#    'Scotland',
#    'offences',
#    'Act',
#    'prosecuted',
#    'penalties',
#    'Act',
#    'recovered',
#    'provisions',
#    'Summary',
#    'Procedure',
#    'Act',
#    'person',
#    'accused',
#    'offence',
#    'Act',
#    'respect',
#    'penalty',
#    'ﬁve',
#    'pounds',
#    'imposed',
#    'appearing',
#    'court',
#    'summary',
#    'jurisdiction',
#    'declare',
#    'objects',
#    'tried',
#    'offence',
#    'court',
#    'summary',
#    'jurisdiction',
#    'proceedings',
#    'taken',
#    'indictment',
#    'Court',
#    'ofjusticiary',
#    'Edinburgh',
#    'circuit',
#    'person',
#    'liable',
#    'penalty',
#    'costs',
#    'shall',
#    'liable',
#    'default',
#    'immediate',
#    'payment',
#    'imprisonment',
#    'term',
#    'exceeding',
#    'months',
#    'penalty',
#    'costs',
#    'sooner',
#    'paid',
#    'Ireland',
#    'offences',
#    'Act',
#    'prosecuted',
#    'penalties',
#    'Act',
#    'recovered',
#    'summary',
#    'manner',
#    'subject',
#    'according',
#    'provisions',
#    'respect',
#    'prosecution',
#    'offences',
#    'recovery',
#    'penalties',
#    'appeal',
#    'Petty',
#    'Sessions',
#    'Ireland',
#    'Act',
#    'Act',
#    'amending',
#    'Dublin',
#    'Acts',
#    'regulatingthe',
#    'powers',
#    'justices',
#    'peace',
#    'police',
#    'Dublin',
#    'metropolis',
#    'penalties',
#    'recovered',
#    'Act',
#    'shall',
#    'applied',
#    'manner',
#    'directed',
#    'Fines',
#    'Ireland',
#    'Act',
#    'Act',
#    'amending',
#    'Ireland',
#    'person',
#    'accused',
#    'court',
#    'summary',
#    'jurisdiction',
#    'offence',
#    'Act',
#    'respect',
#    'penalty',
#    'pounds',
#    'imposed',
#    'accused',
#    'appearing',
#    'court',
#    'summary',
#    'jurisdiction',
#    'declare',
#    'objects',
#    'tried',
#    'offence',
#    'court',
#    'summaryjurisdiction',
#    'court',
#    'summaryjurisdiction',
#    'deal',
#    'case',
#    'respects',
#    'accused',
#    'charged',
#    'indictable',
#    'offence',
#    'offence',
#    'punishable',
#    'summary',
#    'conviction',
#    'offence',
#    'prosecuted',
#    'indictment',
#    'Cruelty',
#    'Animals',
#    'Act',
#    'repealed',
#    'licenses',
#    'certiﬁcates',
#    'granted',
#    'thereunder',
#    'revoked',
#    'provided',
#    'legal',
#    'proceeding',
#    'commenced',
#    'Act',
#    'passing',
#    'Act',
#    'continued',
#    'prosecuted',
#    'defended',
#    'respects',
#    'Act',
#    'passed',
#    'Ilvli',
#    'nrtv',
#    'total',
#    'Abolition',
#    'Vivisection',
#    'Printed',
#    'PEWTRESS',
#    'Little',
#    'Queen',
#    'Street',
#    'London'])]

# %%
for item_id, tokens in head(text_stream(text_dir), n=5):
    print(item_id, tokens[:10])
# Out:
# mc00344_118824_20200131_1256 ['Stereotaxic', 'instruments', 'cat', 'dog', 'rabbit', 'Stereotaxic', 'instruments', 'hold', 'animals', 'paralyzed']
# mc00456-001-bx0007-013-001 ['Abolition', 'Viviseotion', 'ARRANGEMENT', 'CLAUSES', 'Clause', 'Short', 'title', 'Deﬁnition', 'Vivisection', 'Prohibition']
# mc00456-001-bx0002-009-001 ['Birds', 'protected', 'Society', 'Society', 'want', 'Birds', 'Protected', 'word', 'Protection', 'constantly']
# mc00456-001-bx0006-034-001 ['TIMES', 'ARTICLE', 'RESULTS', 'EXPERIMENTS', 'LIVING', 'ANIMALS', 'OCTOBER', 'ANSWERED', 'PROFESSOR', 'LAWSON']
# mc00456-001-bx0004-004-001 ['DEATH', 'Freeman', 'Cruelty', 'Sport', 'following', 'excerpts', 'representing', 'views', 'historian', 'Freeman']

# %%
# You could extract the item_ids from the full text_stream, but in order to not
# tokenize everything when we don't yet need to
item_ids = [get_item_id(fn) for fn in glob.glob(f"{text_dir}/*.txt")]
head(item_ids)
# Out:
# ['mc00344_118824_20200131_1256',
#  'mc00456-001-bx0007-013-001',
#  'mc00456-001-bx0002-009-001',
#  'mc00456-001-bx0006-034-001',
#  'mc00456-001-bx0004-004-001',
#  'mc00620-001-bx0001-034-001',
#  'mc00620-001-bx0001-063-001',
#  'mc00456-001-bx0002-043-001',
#  'mc00456-001-bx0002-042-001',
#  'mc00456-001-bx0002-023-001']

# %%
doc_stream = (tokens for _, tokens in text_stream(text_dir))

# %%
# %time id2word_items = gensim.corpora.Dictionary(doc_stream)
# Out:
# CPU times: user 3min 41s, sys: 663 ms, total: 3min 41s
# Wall time: 8min 20s

# %%
print(id2word_items)
# Out:
# Dictionary(545858 unique tokens: ['Behavioral', 'Detrick', 'Duo', 'Fort', 'Institute']...)

# %%
# Filter words based on occurence in docs
# https://radimrehurek.com/gensim/corpora/dictionary.html#gensim.corpora.dictionary.Dictionary.filter_extremes
id2words_items_filtered = id2word_items.filter_extremes(no_below=2, no_above=1)

# %%
# We're building this for use in the LDA model and so we can save it to disk for re-use
class ItemCorpus(object):
    def __init__(self, text_dir, dictionary):
        self.text_dir = text_dir
        self.dictionary = dictionary
        
    def __iter__(self):
        self.item_ids = []
        for item_id, tokens in text_stream(text_dir):
            self.item_ids.append(item_id)
            yield self.dictionary.doc2bow(tokens)

# %%
item_corpus = ItemCorpus(text_dir, id2word_items)

# %%
# Save serialized corpus for later use
# %time gensim.corpora.MmCorpus.serialize("./items_bow_lg_full.mm", item_corpus)
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:254: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# CPU times: user 3min 35s, sys: 457 ms, total: 3min 35s
# Wall time: 3min 37s

# %%
# You can load models from disk as follows:
loaded_corpus = gensim.corpora.MmCorpus("./items_bow_lg_full.mm")
print(loaded_corpus)
# Out:
# MmCorpus(983 documents, 100000 features, 2695221 non-zero entries)
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:254: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
# Switch to MulticoreLDa
# %time lda_model = gensim.models.LdaModel(loaded_corpus, num_topics=40, id2word=id2word_items, passes=50)
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:254: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# CPU times: user 1h 11min 6s, sys: 27min 45s, total: 1h 38min 51s
# Wall time: 51min 23s

# %%
lda_model.save('animalturn_40_full.model')
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:254: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
lda_model.print_topics(-1)
# Out:
# [(0,
#   '0.003*"Warfare" + 0.003*"blows" + 0.002*"Nations" + 0.002*"mallet" + 0.002*"dislocate" + 0.002*"indicates" + 0.002*"limbs" + 0.002*"violent" + 0.002*"arm" + 0.002*"intense"'),
#  (1,
#   '0.012*"experiments" + 0.006*"disease" + 0.006*"medical" + 0.005*"cases" + 0.005*"animals" + 0.004*"vivisection" + 0.004*"Vivisection" + 0.004*"human" + 0.004*"experiment" + 0.004*"case"'),
#  (2,
#   '0.013*"birds" + 0.008*"species" + 0.008*"food" + 0.007*"insects" + 0.007*"mice" + 0.007*"crops" + 0.006*"hawks" + 0.006*"young" + 0.006*"little" + 0.006*"partridges"'),
#  (3,
#   '0.004*"materials" + 0.003*"vitro" + 0.003*"birds" + 0.003*"INDEX" + 0.003*"shall" + 0.003*"whaling" + 0.003*"MATERIALS" + 0.003*"use" + 0.003*"available" + 0.003*"trade"'),
#  (4,
#   '0.004*"animals" + 0.003*"water" + 0.003*"acid" + 0.002*"animal" + 0.002*"set" + 0.002*"chemical" + 0.002*"effects" + 0.002*"use" + 0.002*"program" + 0.002*"studies"'),
#  (5,
#   '0.100*"birds" + 0.045*"bird" + 0.016*"Bird" + 0.015*"cat" + 0.013*"Conures" + 0.011*"parrots" + 0.011*"cats" + 0.010*"Amazons" + 0.009*"Macaws" + 0.007*"wild"'),
#  (6,
#   '0.012*"dog" + 0.009*"dogs" + 0.007*"vaccination" + 0.006*"serum" + 0.006*"smallpox" + 0.005*"diphtheria" + 0.005*"vaccinated" + 0.004*"days" + 0.004*"years" + 0.004*"children"'),
#  (7,
#   '0.020*"New" + 0.018*"York" + 0.009*"University" + 0.009*"College" + 0.008*"Mass" + 0.008*"Rev" + 0.006*"Animal" + 0.006*"City" + 0.005*"Avenue" + 0.004*"Professor"'),
#  (8,
#   '0.008*"animals" + 0.008*"blood" + 0.007*"animal" + 0.006*"feet" + 0.005*"shall" + 0.005*"Animal" + 0.004*"continued" + 0.004*"State" + 0.004*"cage" + 0.004*"species"'),
#  (9,
#   '0.006*"animals" + 0.004*"animal" + 0.003*"New" + 0.003*"children" + 0.003*"new" + 0.003*"Humane" + 0.003*"Animal" + 0.003*"Washington" + 0.003*"time" + 0.003*"humane"'),
#  (10,
#   '0.014*"whales" + 0.010*"whale" + 0.008*"whaling" + 0.006*"Japan" + 0.006*"species" + 0.005*"Japanese" + 0.004*"year" + 0.004*"IWC" + 0.003*"nations" + 0.003*"United"'),
#  (11,
#   '0.012*"animals" + 0.012*"God" + 0.010*"rights" + 0.010*"life" + 0.009*"man" + 0.009*"animal" + 0.008*"human" + 0.007*"moral" + 0.005*"creatures" + 0.005*"world"'),
#  (12,
#   '0.008*"immunisation" + 0.003*"women" + 0.003*"diphtheria" + 0.003*"Ofﬁcer" + 0.002*"average" + 0.002*"campaign" + 0.002*"trade" + 0.002*"trades" + 0.002*"Birmingham" + 0.002*"League"'),
#  (13,
#   '0.014*"CASH" + 0.013*"WW" + 0.010*"TOTALS" + 0.009*"House" + 0.008*"Ledger" + 0.008*"EXPENSE" + 0.007*"WWW" + 0.007*"Ambulance" + 0.007*"true" + 0.007*"CR"'),
#  (14,
#   '0.008*"Costa" + 0.007*"pub" + 0.006*"Rica" + 0.006*"Science" + 0.005*"AAAS" + 0.005*"Oduber" + 0.005*"President" + 0.005*"American" + 0.005*"Washington" + 0.004*"Arranged"'),
#  (15,
#   '0.023*"Rooks" + 0.007*"Rook" + 0.006*"ﬁeld" + 0.005*"death" + 0.004*"life" + 0.004*"crop" + 0.004*"corn" + 0.004*"La" + 0.004*"wireworm" + 0.003*"earth"'),
#  (16,
#   '0.009*"animals" + 0.006*"animal" + 0.004*"use" + 0.003*"rate" + 0.003*"food" + 0.003*"water" + 0.003*"time" + 0.003*"cage" + 0.002*"method" + 0.002*"control"'),
#  (17,
#   '0.007*"animals" + 0.005*"man" + 0.004*"men" + 0.004*"time" + 0.003*"animal" + 0.003*"life" + 0.003*"great" + 0.003*"cruelty" + 0.002*"good" + 0.002*"way"'),
#  (18,
#   '0.018*"Mrs" + 0.017*"hon" + 0.013*"branch" + 0.012*"sec" + 0.011*"RSPCA" + 0.009*"Mr" + 0.008*"aux" + 0.007*"Miss" + 0.006*"animals" + 0.005*"Inspector"'),
#  (19,
#   '0.027*"Schweitzer" + 0.013*"Albert" + 0.009*"Welfare" + 0.009*"Medal" + 0.008*"Institute" + 0.008*"award" + 0.008*"Animal" + 0.007*"medal" + 0.006*"Stevens" + 0.005*"presented"'),
#  (20,
#   '0.008*"Pearson" + 0.007*"poems" + 0.006*"Jean" + 0.005*"Thy" + 0.005*"Tom" + 0.005*"William" + 0.004*"anthology" + 0.004*"Robert" + 0.003*"Susan" + 0.003*"Stafford"'),
#  (21,
#   '0.011*"New" + 0.010*"York" + 0.010*"Street" + 0.009*"slaughter" + 0.008*"State" + 0.008*"humane" + 0.007*"animals" + 0.006*"article" + 0.006*"Road" + 0.006*"shall"'),
#  (22,
#   '0.013*"animals" + 0.011*"New" + 0.011*"Dear" + 0.010*"JOHN" + 0.009*"legislation" + 0.009*"York" + 0.008*"letter" + 0.008*"Senate" + 0.008*"treatment" + 0.008*"Bemelmans"'),
#  (23,
#   '0.017*"Society" + 0.008*"horse" + 0.007*"Miss" + 0.007*"President" + 0.006*"Cruelty" + 0.006*"Animals" + 0.006*"Secretary" + 0.006*"John" + 0.005*"Prevention" + 0.005*"Humane"'),
#  (24,
#   '0.005*"Animals" + 0.005*"animals" + 0.005*"Humane" + 0.004*"Society" + 0.004*"dog" + 0.004*"Boston" + 0.003*"little" + 0.003*"birds" + 0.003*"Education" + 0.003*"cts"'),
#  (25,
#   '0.009*"grit" + 0.007*"feeding" + 0.006*"partridges" + 0.005*"WHALES" + 0.005*"commercial" + 0.004*"birds" + 0.004*"undersigned" + 0.004*"GREAT" + 0.003*"KILLING" + 0.003*"world"'),
#  (26,
#   '0.058*"Miss" + 0.015*"Society" + 0.010*"Esq" + 0.007*"Hon" + 0.006*"animals" + 0.005*"meeting" + 0.005*"London" + 0.005*"Lady" + 0.005*"Secretary" + 0.004*"Sir"'),
#  (27,
#   '0.032*"animal" + 0.025*"shall" + 0.016*"person" + 0.016*"animals" + 0.008*"section" + 0.006*"cruelty" + 0.006*"misdemeanor" + 0.006*"owner" + 0.006*"necessary" + 0.005*"food"'),
#  (28,
#   '0.011*"ASPCA" + 0.010*"dog" + 0.009*"animals" + 0.009*"New" + 0.009*"York" + 0.005*"year" + 0.005*"animal" + 0.004*"dogs" + 0.004*"pet" + 0.004*"Hospital"'),
#  (29,
#   '0.005*"New" + 0.004*"York" + 0.004*"time" + 0.003*"animals" + 0.003*"dog" + 0.003*"water" + 0.003*"children" + 0.003*"school" + 0.003*"loss" + 0.003*"good"'),
#  (30,
#   '0.013*"said" + 0.006*"animals" + 0.004*"animal" + 0.004*"dog" + 0.004*"dogs" + 0.003*"says" + 0.003*"people" + 0.003*"years" + 0.003*"like" + 0.003*"year"'),
#  (31,
#   '0.017*"animals" + 0.011*"animal" + 0.010*"research" + 0.005*"Act" + 0.005*"humane" + 0.005*"Animal" + 0.004*"shall" + 0.004*"use" + 0.004*"dogs" + 0.004*"Secretary"'),
#  (32,
#   '0.009*"pavement" + 0.008*"block" + 0.007*"wood" + 0.007*"pavements" + 0.006*"paving" + 0.006*"streets" + 0.006*"New" + 0.005*"York" + 0.005*"horses" + 0.005*"horse"'),
#  (33,
#   '0.008*"animals" + 0.004*"mm" + 0.004*"ta" + 0.004*"time" + 0.004*"work" + 0.003*"tha" + 0.003*"far" + 0.003*"animal" + 0.003*"good" + 0.003*"know"'),
#  (34,
#   '0.020*"humane" + 0.018*"slaughter" + 0.010*"New" + 0.009*"methods" + 0.008*"Senator" + 0.008*"meat" + 0.007*"slaughtering" + 0.007*"York" + 0.006*"legislation" + 0.005*"packers"'),
#  (35,
#   '0.013*"ISBN" + 0.007*"paper" + 0.006*"pp" + 0.005*"hardcover" + 0.004*"book" + 0.004*"animals" + 0.003*"Box" + 0.003*"Animal" + 0.002*"Stevens" + 0.002*"Szasz"'),
#  (36,
#   '0.008*"animals" + 0.006*"Animal" + 0.005*"animal" + 0.004*"Act" + 0.004*"research" + 0.003*"Society" + 0.003*"use" + 0.003*"species" + 0.002*"New" + 0.002*"trade"'),
#  (37,
#   '0.010*"Animal" + 0.009*"animals" + 0.007*"AWI" + 0.006*"Institute" + 0.006*"Welfare" + 0.005*"animal" + 0.005*"Animals" + 0.004*"Washington" + 0.004*"year" + 0.004*"meeting"'),
#  (38,
#   '0.008*"Veterinary" + 0.005*"AVMA" + 0.004*"American" + 0.004*"Association" + 0.004*"University" + 0.004*"New" + 0.004*"July" + 0.004*"Animal" + 0.003*"Medicine" + 0.003*"Medical"'),
#  (39,
#   '0.001*"PRIVILEGE" + 0.001*"catapult" + 0.000*"FOXES" + 0.000*"pestered" + 0.000*"Sporty" + 0.000*"suddenness" + 0.000*"MOBLEY" + 0.000*"Subscriber" + 0.000*"heaved" + 0.000*"Misery"')]

# %%
# Write up what this means
lda_model[loaded_corpus[0]]
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:254: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# [(4, 0.14879134),
#  (8, 0.045974493),
#  (16, 0.28724435),
#  (30, 0.06475382),
#  (33, 0.18565476),
#  (36, 0.23535001),
#  (38, 0.026908671)]

# %%
import pyLDAvis
import pyLDAvis.gensim
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-fc42def2ed73> in <module>()
# ----> 1 import pyLDAvis
#       2 import pyLDAvis.gensim
#
# ModuleNotFoundError: No module named 'pyLDAvis'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pyLDAvis.enable_notebook()

# %%
pyLDAvis.gensim.prepare(lda_model, loaded_corpus, id2word_items)

# %%
#visualization following https://www.kaggle.com/ykhorramz/lda-and-t-sne-interactive-visualization#

# %%
def explore_topic(lda_model, topic_number, topn, output=True):
    """
    accepts an ldamodel, a topic number and topn terms of interest
    prints a formatted list of the topn terms
    """
    terms = []
    for term, frequency in lda_model.show_topic(topic_number, topn=topn):
        terms += [term]
        if output:
            print(u'{:20} {:.3f}'.format(term, round(frequency, 3)))
    return terms

# %%
topic_summaries = []
print(u'{:20} {}'.format(u'term', u'frequency') + u'\n')
for i in range(20):
    print("Topic " + str(i) + " |---------------------\n")
    tmp = explore_topic(lda_model, topic_number=i, topn=10, output=True)
    topic_summaries += [tmp[:5]]
    print
# Out:
# term                 frequency
#
# Topic 0 |---------------------
#
# Mrs                  0.019
# hon                  0.019
# branch               0.014
# sec                  0.014
# RSPCA                0.012
# Mr                   0.010
# aux                  0.009
# Miss                 0.007
# animals              0.007
# Inspector            0.005
# Topic 1 |---------------------
#
# rabbits              0.013
# trap                 0.008
# true                 0.006
# traps                0.006
# rabbit               0.005
# time                 0.005
# fact                 0.005
# use                  0.004
# necessary            0.004
# certain              0.004
# Topic 2 |---------------------
#
# Animals              0.006
# Humane               0.006
# Society              0.005
# Boston               0.005
# animals              0.005
# dog                  0.004
# cts                  0.004
# little               0.003
# Education            0.003
# birds                0.003
# Topic 3 |---------------------
#
# animals              0.007
# man                  0.004
# animal               0.004
# life                 0.004
# time                 0.003
# little               0.003
# like                 0.003
# great                0.003
# birds                0.003
# cruelty              0.002
# Topic 4 |---------------------
#
# Rooks                0.015
# ﬁeld                 0.007
# Rook                 0.005
# corn                 0.004
# years                0.004
# crop                 0.003
# glacier              0.003
# food                 0.003
# cat                  0.003
# winter               0.003
# Topic 5 |---------------------
#
# pavement             0.008
# block                0.007
# wood                 0.006
# pavements            0.006
# paving               0.006
# streets              0.006
# horses               0.005
# New                  0.005
# action               0.005
# York                 0.005
# Topic 6 |---------------------
#
# birds                0.015
# bird                 0.009
# rights               0.005
# species              0.005
# time                 0.005
# Animal               0.005
# te                   0.004
# Bird                 0.004
# trade                0.004
# Moore                0.004
# Topic 7 |---------------------
#
# species              0.004
# animals              0.003
# years                0.003
# year                 0.002
# time                 0.002
# wildlife             0.002
# birds                0.002
# animal               0.002
# water                0.002
# use                  0.002
# Topic 8 |---------------------
#
# Aux                  0.006
# Streak               0.002
# temple               0.002
# Gaskoin              0.002
# Stapledon            0.002
# Abby                 0.002
# Jaques               0.001
# PLUMMER              0.001
# Walmsley             0.001
# Faith                0.001
# Topic 9 |---------------------
#
# animals              0.007
# rate                 0.006
# response             0.006
# responses            0.004
# stimulus             0.004
# Fig                  0.004
# animal               0.004
# research             0.004
# behavior             0.004
# control              0.003
# Topic 10 |---------------------
#
# ﬁned                 0.003
# Typical              0.002
# Eng                  0.002
# Man                  0.002
# labour               0.001
# Cases                0.001
# Causes               0.001
# MISS                 0.001
# Performs             0.001
# castrating           0.001
# Topic 11 |---------------------
#
# dog                  0.011
# ASPCA                0.011
# animals              0.011
# New                  0.009
# York                 0.009
# animal               0.006
# year                 0.006
# dogs                 0.005
# pet                  0.005
# Hospital             0.004
# Topic 12 |---------------------
#
# Society              0.024
# Miss                 0.011
# President            0.011
# Secretary            0.010
# Humane               0.008
# John                 0.007
# horse                0.007
# Animals              0.006
# Cruelty              0.006
# Prevention           0.006
# Topic 13 |---------------------
#
# horse                0.007
# ll                   0.007
# dog                  0.005
# Society              0.005
# street               0.005
# said                 0.005
# society              0.005
# Cruelty              0.004
# horses               0.004
# Animals              0.004
# Topic 14 |---------------------
#
# whales               0.023
# whaling              0.022
# Japan                0.015
# whale                0.013
# Japanese             0.010
# IWC                  0.008
# Washington           0.005
# Whaling              0.005
# commercial           0.005
# nations              0.005
# Topic 15 |---------------------
#
# animals              0.016
# Animal               0.010
# animal               0.010
# research             0.009
# Act                  0.007
# Welfare              0.005
# Animals              0.005
# use                  0.004
# Secretary            0.004
# laboratory           0.004
# Topic 16 |---------------------
#
# animals              0.006
# New                  0.005
# York                 0.004
# dog                  0.003
# school               0.003
# animal               0.003
# time                 0.003
# children             0.003
# water                0.003
# Animal               0.003
# Topic 17 |---------------------
#
# Belinda              0.010
# Woodpigeons          0.004
# Nlrs                 0.001
# HOUSING              0.000
# animals              0.000
# said                 0.000
# birds                0.000
# Society              0.000
# materials            0.000
# time                 0.000
# Topic 18 |---------------------
#
# animal               0.033
# shall                0.029
# person               0.017
# animals              0.017
# section              0.011
# cruelty              0.006
# necessary            0.006
# misdemeanor          0.006
# owner                0.005
# dog                  0.005
# Topic 19 |---------------------
#
# Pearson              0.007
# poems                0.006
# Jean                 0.005
# Mary                 0.004
# William              0.004
# Robert               0.003
# Susan                0.003
# Animals              0.003
# Stafford             0.003
# poem                 0.003

# %%
topic_summaries
# Out:
# [['Mrs', 'hon', 'branch', 'sec', 'RSPCA'],
#  ['rabbits', 'trap', 'true', 'traps', 'rabbit'],
#  ['Animals', 'Humane', 'Society', 'Boston', 'animals'],
#  ['animals', 'man', 'animal', 'life', 'time'],
#  ['Rooks', 'ﬁeld', 'Rook', 'corn', 'years'],
#  ['pavement', 'block', 'wood', 'pavements', 'paving'],
#  ['birds', 'bird', 'rights', 'species', 'time'],
#  ['species', 'animals', 'years', 'year', 'time'],
#  ['Aux', 'Streak', 'temple', 'Gaskoin', 'Stapledon'],
#  ['animals', 'rate', 'response', 'responses', 'stimulus'],
#  ['ﬁned', 'Typical', 'Eng', 'Man', 'labour'],
#  ['dog', 'ASPCA', 'animals', 'New', 'York'],
#  ['Society', 'Miss', 'President', 'Secretary', 'Humane'],
#  ['horse', 'll', 'dog', 'Society', 'street'],
#  ['whales', 'whaling', 'Japan', 'whale', 'Japanese'],
#  ['animals', 'Animal', 'animal', 'research', 'Act'],
#  ['animals', 'New', 'York', 'dog', 'school'],
#  ['Belinda', 'Woodpigeons', 'Nlrs', 'HOUSING', 'animals'],
#  ['animal', 'shall', 'person', 'animals', 'section'],
#  ['Pearson', 'poems', 'Jean', 'Mary', 'William']]

# %%
import pandas as pd

# %%
source_id = pd.Series(item_ids)

# %%
lda_model[loaded_corpus[100]]
# Out:
# [(0, 0.22041495),
#  (3, 0.56582475),
#  (13, 0.033205844),
#  (18, 0.09440457),
#  (37, 0.08468529)]

# %%
# Create headers for our csv file for each topic
headers = ["source_id"]
for i in range(20):
    headers.append(f"topic-{i}")

# %%
headers[:5]
# Out:
# ['source_id', 'topic-0', 'topic-1', 'topic-2', 'topic-3']

# %%
df = pd.DataFrame(columns=headers)
df
# Out:
# Empty DataFrame
# Columns: [source_id, topic-0, topic-1, topic-2, topic-3, topic-4, topic-5, topic-6, topic-7, topic-8, topic-9, topic-10, topic-11, topic-12, topic-13, topic-14, topic-15, topic-16, topic-17, topic-18, topic-19]
# Index: []
#
# [0 rows x 21 columns]

# %%
for i in range(len(item_ids)):
    item_id = item_ids[i]
    new_row = [item_id]
    for k, i in lda_model[loaded_corpus[i]]:
        new_row.append(i)
    df.loc[item_id] = new_row
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-534a5c3305db> in <module>
#       4     for k, i in lda_model[loaded_corpus[i]]:
#       5         new_row.append(i)
# ----> 6     df.loc[item_id] = new_row
#
# ~/Library/Caches/pypoetry/virtualenvs/animal-turn-4Iy9RDyX-py3.8/lib/python3.8/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     669             key = com.apply_if_callable(key, self.obj)
#     670         indexer = self._get_setitem_indexer(key)
# --> 671         self._setitem_with_indexer(indexer, value)
#     672
#     673     def _validate_key(self, key, axis: int):
#
# ~/Library/Caches/pypoetry/virtualenvs/animal-turn-4Iy9RDyX-py3.8/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     873
#     874             if missing:
# --> 875                 return self._setitem_with_indexer_missing(indexer, value)
#     876
#     877         # set
#
# ~/Library/Caches/pypoetry/virtualenvs/animal-turn-4Iy9RDyX-py3.8/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    1117                     # must have conforming columns
#    1118                     if len(value) != len(self.obj.columns):
# -> 1119                         raise ValueError("cannot set a row with mismatched columns")
#    1120
#    1121                 value = Series(value, index=self.obj.columns, name=indexer)
#
# ValueError: cannot set a row with mismatched columns
